# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("pandas/Euro_2012_stats_TEAM.csv")

# %%
data.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
data.columns = data.columns.str.lower().str.replace(" ","_")

# %%
data.groupby("team")["goals"].sum().sort_values(ascending = False).head(1)
# Out:
# team
# Spain    12
# Name: goals, dtype: int64

# %%
data.groupby("team")["total_shots_(inc._blocked)"].sum().sort_values(ascending = False).head(1)
# Out:
# team
# Italy    110
# Name: total_shots_(inc._blocked), dtype: int64

# %%
data[data["team"] == "Italy"]
# Out:
#     team  goals  shots_on_target  shots_off_target shooting_accuracy  \
# 7  Italy      6               34                45             43.0%
#
#   %_goals-to-shots  total_shots_(inc._blocked)  hit_woodwork  penalty_goals  \
# 7             7.5%                         110             2              0
#
#    penalties_not_scored  ...  saves_made  saves-to-shots_ratio  fouls_won  \
# 7                     0  ...          20                 74.1%        101
#
#   fouls_conceded  offsides  yellow_cards  red_cards  subs_on  subs_off  \
# 7             89        16            16          0       18        18
#
#    players_used
# 7            19
#
# [1 rows x 35 columns]

# %%
data.groupby("team")["yellow_cards"].sum().idxmax()
# Out:
# 'Italy'

# %%
data.head()
# Out:
#              team  goals  shots_on_target  shots_off_target shooting_accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   %_goals-to-shots  total_shots_(inc._blocked)  hit_woodwork  penalty_goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
data.groupby("team")["shooting_accuracy"].sum().sort_values(ascending = False).head(3)
# Out:
# team
# Spain      55.9%
# Croatia    51.9%
# Denmark    50.0%
# Name: shooting_accuracy, dtype: object

# %%
data.team.sort_values(by = "shooting_accuracy", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data.team.sort_values(by = "shooting_accuracy", ascending = False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
data.sort_values(by = "goals",ascending = False)[["team","goals"]].head()
# Out:
#         team  goals
# 13     Spain     12
# 5    Germany     10
# 10  Portugal      6
# 7      Italy      6
# 14    Sweden      5

# %%
data["shooting_accuracy"] = data["shooting_accuracy"].str.replace("%","")

# %%
avg = data["shooting_accuracy"].astype(float).mean();avg
# Out:
# np.float64(39.71875)

# %%
data["shooting_accuracy"] = data["shooting_accuracy"].astype(float)

# %%
data[data["shooting_accuracy"] > avg][["team", "shooting_accuracy"]]
# Out:
#               team  shooting_accuracy
# 0          Croatia               51.9
# 1   Czech Republic               41.9
# 2          Denmark               50.0
# 3          England               50.0
# 5          Germany               47.8
# 7            Italy               43.0
# 13           Spain               55.9
# 14          Sweden               47.2

# %%
data.head()
# Out:
#              team  goals  shots_on_target  shots_off_target  \
# 0         Croatia      4               13                12
# 1  Czech Republic      4               13                18
# 2         Denmark      4               10                10
# 3         England      5               11                18
# 4          France      3               22                24
#
#    shooting_accuracy %_goals-to-shots  total_shots_(inc._blocked)  \
# 0               51.9            16.0%                          32
# 1               41.9            12.9%                          39
# 2               50.0            20.0%                          27
# 3               50.0            17.2%                          40
# 4               37.9             6.5%                          65
#
#    hit_woodwork  penalty_goals  penalties_not_scored  ...  saves_made  \
# 0             0              0                     0  ...          13
# ...

# %%
data_fouls = data[["team","goals","yellow_cards","fouls_conceded"]];data_fouls.head()
# Out:
#              team  goals  yellow_cards  fouls_conceded
# 0         Croatia      4             9              62
# 1  Czech Republic      4             7              73
# 2         Denmark      4             4              38
# 3         England      5             5              45
# 4          France      3             6              51

# %% [raw]
# Hem sarı kartı 10’dan fazla olan hem de faul sayısı 100’den fazla olan takımlar hangileridir?

# %%
data_fouls.query("yellow_cards > 10 and fouls_conceded > 50")
# Out:
#         team  goals  yellow_cards  fouls_conceded
# 7      Italy      6            16              89
# 10  Portugal      6            12              90
# 13     Spain     12            11              83

# %%
data_fouls[data_fouls["yellow_cards"] > 10]
# Out:
#         team  goals  yellow_cards  fouls_conceded
# 7      Italy      6            16              89
# 10  Portugal      6            12              90
# 13     Spain     12            11              83

# %%
data_fouls[data_fouls["fouls_conceded"] > 50]
# Out:
#                    team  goals  yellow_cards  fouls_conceded
# 0               Croatia      4             9              62
# 1        Czech Republic      4             7              73
# 4                France      3             6              51
# 7                 Italy      6            16              89
# 9                Poland      2             7              56
# 10             Portugal      6            12              90
# 11  Republic of Ireland      1             6              51
# 13                Spain     12            11              83
# 14               Sweden      5             7              51

# %%
data_fouls[
            (data_fouls["yellow_cards"] > 10) & 
            (data_fouls["fouls_conceded"] > 50)
            ]
# Out:
#         team  goals  yellow_cards  fouls_conceded
# 7      Italy      6            16              89
# 10  Portugal      6            12              90
# 13     Spain     12            11              83

# %%
data[["team","yellow_cards"]].sort_values(by = "yellow_cards",ascending = False).head()
# Out:
#         team  yellow_cards
# 7      Italy            16
# 10  Portugal            12
# 13     Spain            11
# 0    Croatia             9
# 6     Greece             9

# %%
data.sort_values(by = "shooting_accuracy",ascending = False)[["team","shooting_accuracy"]].head(1)
# Out:
#      team  shooting_accuracy
# 13  Spain               55.9

# %%
#Find the teams that have lowest and highest number of yellow cards. 
#Note that more than one country can have the same maximum number or minimum number of yellow cards.

# %% [raw]
# Problem 1.
# Euro 2012 stats TEAM.csv file contains statistics of the teams that attended Europen Cup 2012. Using this data do the following tasks:
# a) Find the teams that have lowest and highest number of yellow cards. Note that more than one country can have the same maximum number or minimum number of yellow cards.
# b) Find the team that has the best shooting accuracy.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
data.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
data["Yellow Cards"].sort_values(ascending = False).head()
# Out:
# 7     16
# 10    12
# 13    11
# 0      9
# 6      9
# Name: Yellow Cards, dtype: int64

# %%
data.sort_values(by = "Yellow Cards", ascending = False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 6                Greece      5                8                18
# 14               Sweden      5               17                19
# 9                Poland      2               15                23
# 1        Czech Republic      4               13                18
# 12               Russia      5                9                31
# 11  Republic of Ireland      1                7                12
# 4                France      3               22                24
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# ...

# %%
data.sort_values(by = "Yellow Cards", ascending = False)[["Team","Yellow Cards"]].head() #Italy have the max number of yellow card
# Out:
#         Team  Yellow Cards
# 7      Italy            16
# 10  Portugal            12
# 13     Spain            11
# 0    Croatia             9
# 6     Greece             9

# %%
data.sort_values(by = "Yellow Cards")[["Team","Yellow Cards"]].head()  #Denmark and Germany have the min number of yellow card
# Out:
#            Team  Yellow Cards
# 2       Denmark             4
# 5       Germany             4
# 3       England             5
# 8   Netherlands             5
# 15      Ukraine             5

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %% [raw]
# section b - Find the team that has the best shooting accuracy.

# %%
data.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
data["Shooting Accuracy"]
# Out:
# 0     51.9%
# 1     41.9%
# 2     50.0%
# 3     50.0%
# 4     37.9%
# 5     47.8%
# 6     30.7%
# 7     43.0%
# 8     25.0%
# 9     39.4%
# 10    34.3%
# 11    36.8%
# 12    22.5%
# 13    55.9%
# 14    47.2%
# 15    21.2%
# Name: Shooting Accuracy, dtype: object

# %%
data.sort_values(by = ("Shooting Accuracy"),ascending = False)[["Team", "Shooting Accuracy"]].head(3)
# Out:
#        Team Shooting Accuracy
# 13    Spain             55.9%
# 0   Croatia             51.9%
# 2   Denmark             50.0%

# %%
data.sort_values(by = ("Shooting Accuracy"),ascending = False)[["Team", "Shooting Accuracy"]].iloc[0]
# Out:
# Team                 Spain
# Shooting Accuracy    55.9%
# Name: 13, dtype: object

# %%
print("The team that has the highest scoring accuracy: {}".format(data.sort_values(by="Shooting Accuracy", ascending=False)["Team"].iloc[0]))
# Out:
# The team that has the highest scoring accuracy: Spain

# %%
data.columns = data.columns.str.lower().str.replace(" ","_")

# %%
data.head()
# Out:
#              team  goals  shots_on_target  shots_off_target shooting_accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   %_goals-to-shots  total_shots_(inc._blocked)  hit_woodwork  penalty_goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
data.columns
# Out:
# Index(['team', 'goals', 'shots_on_target', 'shots_off_target',
#        'shooting_accuracy', '%_goals-to-shots', 'total_shots_(inc._blocked)',
#        'hit_woodwork', 'penalty_goals', 'penalties_not_scored', 'headed_goals',
#        'passes', 'passes_completed', 'passing_accuracy', 'touches', 'crosses',
#        'dribbles', 'corners_taken', 'tackles', 'clearances', 'interceptions',
#        'clearances_off_line', 'clean_sheets', 'blocks', 'goals_conceded',
#        'saves_made', 'saves-to-shots_ratio', 'fouls_won', 'fouls_conceded',
#        'offsides', 'yellow_cards', 'red_cards', 'subs_on', 'subs_off',
#        'players_used'],
#       dtype='object')

# %%
data = data.drop(['shots_on_target', 'shots_off_target',
       'shooting_accuracy', '%_goals-to-shots', 'total_shots_(inc._blocked)','passes', 'passes_completed', 'passing_accuracy', 'touches', 'crosses',
       'dribbles', 'corners_taken', 'tackles', 'clearances', 'interceptions',
       'clearances_off_line', 'clean_sheets', 'blocks', 'goals_conceded',
       'saves_made', 'saves-to-shots_ratio', 'fouls_won', 'fouls_conceded',
       'offsides'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data = data.drop(['shots_on_target', 'shots_off_target',
#       2        'shooting_accuracy', '%_goals-to-shots', 'total_shots_(inc._blocked)','passes', 'passes_completed', 'passing_accuracy', 'touches', 'crosses',
#       3        'dribbles', 'corners_taken', 'tackles', 'clearances', 'interceptions',
#       4        'clearances_off_line', 'clean_sheets', 'blocks', 'goals_conceded',
#       5        'saves_made', 'saves-to-shots_ratio', 'fouls_won', 'fouls_conceded',
#       6        'offsides'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
# ...

# %%
data2 = data[['team', 'goals', 'shots_on_target','shooting_accuracy', '%_goals-to-shots']];data2
# Out:
#                    team  goals  shots_on_target shooting_accuracy  \
# 0               Croatia      4               13             51.9%
# 1        Czech Republic      4               13             41.9%
# 2               Denmark      4               10             50.0%
# 3               England      5               11             50.0%
# 4                France      3               22             37.9%
# 5               Germany     10               32             47.8%
# 6                Greece      5                8             30.7%
# 7                 Italy      6               34             43.0%
# 8           Netherlands      2               12             25.0%
# 9                Poland      2               15             39.4%
# 10             Portugal      6               22             34.3%
# 11  Republic of Ireland      1                7             36.8%
# 12               Russia      5                9             22.5%
# ...

# %%
data2.sort_values(by = "goals",ascending = False).head()
# Out:
#         team  goals  shots_on_target shooting_accuracy %_goals-to-shots
# 13     Spain     12               42             55.9%            16.0%
# 5    Germany     10               32             47.8%            15.6%
# 10  Portugal      6               22             34.3%             9.3%
# 7      Italy      6               34             43.0%             7.5%
# 14    Sweden      5               17             47.2%            13.8%

# %% [raw]
# The csv file AutoSurvey.csv contains a sample of data about vehicles owned, whether they were purchased new or used, and other types of data. The data file looks like the figure below.
# a- Print average mileage for each car type. Average of mileages should be grouped into columns as New and Used, as shown below
# b- For each car type find the difference between maximum and minimum Vehichle Age

# %%
auto = pd.read_csv("AutoSurvey.csv")

# %%
auto.head()
# Out:
#    Gender       Type Purchased  Vehicle_Age  Mileage   MPG
# 0    Male   Mid-size      Used         15.0   127233  28.7
# 1  Female   Mid-size       New          1.0    23970  43.4
# 2    Male      Small       New          7.0    77392  24.0
# 3  Female  Large SUV      Used         14.0   185397  15.2
# 4  Female      Small       New          2.0    26001  37.0

# %%
#Hem new olan
#Hem de mpg ortalamanın ÜSTÜNDE olan

# %%
auto.columns = auto.columns.str.lower().str.replace(" ","")

# %%
len(auto)
# Out:
# 23

# %%
mpg_mean = auto["mpg"].mean();mpg_mean
# Out:
# np.float64(29.078260869565216)

# %%
auto[auto["mpg"] > mpg_mean]
# Out:
#     gender      type purchased  vehicle_age  mileage   mpg
# 1   Female  Mid-size       New          1.0    23970  43.4
# 4   Female     Small       New          2.0    26001  37.0
# 6     Male     Small      Used          6.0    72083  45.7
# 7     Male     Small       New         11.0   165353  42.0
# 8     Male     Small      Used         13.0   205288  33.0
# 9   Female     Small       New          7.0   142897  31.0
# 15  Female     Small      Used         10.0   105628  35.0
# 16  Female     Small       New          5.0    48678  30.4
# 17    Male  Mid-size       New          0.5     6849  40.2
# 18  Female     Small      Used         10.0   137941  30.0
# 21  Female     Small      Used         12.0   134172  31.0

# %%
auto[auto["purchased"] == "New"]
auto.query("mpg > mpg_mean and purchased == 'New'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~\anaconda3\Lib\collections\__init__.py:1019, in ChainMap.__getitem__(self, key)
#    1018         pass
# -> 1019 return self.__missing__(key)
#
# File ~\anaconda3\Lib\collections\__init__.py:1011, in ChainMap.__missing__(self, key)
#    1010 def __missing__(self, key):
# -> 1011     raise KeyError(key)
#
# KeyError: 'mpg_mean'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
auto[
(auto["purchased"] == "New") &
(auto["mpg"] > mpg_mean) 
].sort_values(by = "mpg",ascending = False)

# %%
auto.head()

# %%
#En yüksek ortalama mpg'ye sahip
#araç modeli hangisidir ve bu ortalama kaçtır?

# %%
auto.mpg.sort_values(ascending = False).idxmax()

# %%
auto.iloc[6]

# %%
auto["mileage_per_year"] = auto["mileage"] / auto["vehicle_age"];auto.head()
auto["mileage_per_year"].round()
# Out:
# 0      8482.0
# 1     23970.0
# 2     11056.0
# 3     13243.0
# 4     13000.0
# 5     20071.0
# 6     12014.0
# 7     15032.0
# 8     15791.0
# 9     20414.0
# 10    13042.0
# 11    10806.0
# 12    11057.0
# 13    13816.0
# 14    18701.0
# 15    10563.0
# 16     9736.0
# 17    13698.0
# 18    13794.0
# 19     7456.0
# 20     6126.0
# 21    11181.0
# 22     7199.0
# Name: mileage_per_year, dtype: float64

# %%
auto.head()
# Out:
#    gender       type purchased  vehicle_age  mileage   mpg  mileage_per_year
# 0    Male   Mid-size      Used         15.0   127233  28.7       8482.200000
# 1  Female   Mid-size       New          1.0    23970  43.4      23970.000000
# 2    Male      Small       New          7.0    77392  24.0      11056.000000
# 3  Female  Large SUV      Used         14.0   185397  15.2      13242.642857
# 4  Female      Small       New          2.0    26001  37.0      13000.500000

# %%
auto.pivot_table(index = "type", columns = "purchased", values = "mpg")

# %% [raw]
# Type bazında tek bir tablo üret ve şu metrikler olsun:
#
# araç sayısı (satır sayısı)
#
# ortalama MPG
#
# maksimum MPG
#
# Vehicle_Age farkı: max(Vehicle_Age) - min(Vehicle_Age)
#
# ortalama Mileage_per_Year

# %%
auto.groupby("type").agg(
    vehicle_count = ("type","size"),
    avg_mpg = ("mpg","mean"),
    max_mpg = ("mpg","max"),
    vehicle_age_diff = ("vehicle_age", lambda x:x.max() - x.min()),
    avg_mileage_py = ("mileage_per_year", "mean"))
# Out:
#            vehicle_count    avg_mpg  max_mpg  vehicle_age_diff  avg_mileage_py
# type
# Large SUV              2  18.100000     21.0              7.00    15971.678571
# Mid-size               5  33.520000     43.4             14.75    13433.023333
# Minivan                2  16.000000     20.0              5.00    16556.579365
# Small                 11  33.372727     45.7             11.00    13058.015091
# Small SUV              3  21.966667     24.9             10.00     8129.251832

# %% [raw]
# E) Kazananı Bul (sort + idxmax)
# “En verimli araç tipi”ni şu skorla tanımla:
# Efficiency_Score = MPG / Mileage_per_Year
# Her satır için bu skoru hesapla.
# Sonra Type bazında ortalama Efficiency_Score hesapla.
# En yüksek ortalama skora sahip Type hangisi? (idxmax)
# Bu Type’ın skor değeri kaç? (max)

# %%
auto["efficiency_score"] = auto.mpg / auto.mileage_per_year

# %%
auto.head()
# Out:
#    gender       type purchased  vehicle_age  mileage   mpg  mileage_per_year  \
# 0    Male   Mid-size      Used         15.0   127233  28.7       8482.200000
# 1  Female   Mid-size       New          1.0    23970  43.4      23970.000000
# 2    Male      Small       New          7.0    77392  24.0      11056.000000
# 3  Female  Large SUV      Used         14.0   185397  15.2      13242.642857
# 4  Female      Small       New          2.0    26001  37.0      13000.500000
#
#    efficiency_score
# 0          0.003384
# 1          0.001811
# 2          0.002171
# 3          0.001148
# 4          0.002846

# %%
auto.groupby("type")["efficiency_score"].mean().round(4)
# Out:
# type
# Large SUV    0.0011
# Mid-size     0.0028
# Minivan      0.0010
# Small        0.0026
# Small SUV    0.0029
# Name: efficiency_score, dtype: float64

# %%
auto.groupby("type")["efficiency_score"].mean().idxmax()
# Out:
# 'Small SUV'

# %%
auto.groupby("type")["efficiency_score"].mean().max()
# Out:
# 0.002872855473486769

# %%
auto.query("mpg > @mpg_mean and purchased == 'New'")
# Out:
#     gender      type purchased  vehicle_age  mileage   mpg
# 1   Female  Mid-size       New          1.0    23970  43.4
# 4   Female     Small       New          2.0    26001  37.0
# 7     Male     Small       New         11.0   165353  42.0
# 9   Female     Small       New          7.0   142897  31.0
# 16  Female     Small       New          5.0    48678  30.4
# 17    Male  Mid-size       New          0.5     6849  40.2

# %% [raw]
# Purchased == "New" ama Vehicle_Age >= 5 olanlar
#
# Purchased == "Used" ama Vehicle_Age <= 1 olanlar

# %%
auto.head()
# Out:
#    gender       type purchased  vehicle_age  mileage   mpg  mileage_per_year  \
# 0    Male   Mid-size      Used         15.0   127233  28.7       8482.200000
# 1  Female   Mid-size       New          1.0    23970  43.4      23970.000000
# 2    Male      Small       New          7.0    77392  24.0      11056.000000
# 3  Female  Large SUV      Used         14.0   185397  15.2      13242.642857
# 4  Female      Small       New          2.0    26001  37.0      13000.500000
#
#    efficiency_score
# 0          0.003384
# 1          0.001811
# 2          0.002171
# 3          0.001148
# 4          0.002846

# %%
auto.query("purchased == 'New' and vehicle_age >= 5")
# Out:
#     gender       type purchased  vehicle_age  mileage   mpg  mileage_per_year  \
# 2     Male      Small       New          7.0    77392  24.0      11056.000000
# 5   Female    Minivan       New          9.0   180643  20.0      20071.444444
# 7     Male      Small       New         11.0   165353  42.0      15032.090909
# 9   Female      Small       New          7.0   142897  31.0      20413.857143
# 14  Female  Large SUV       New          7.0   130905  21.0      18700.714286
# 16  Female      Small       New          5.0    48678  30.4       9735.600000
#
#     efficiency_score
# 2           0.002171
# 5           0.000996
# 7           0.002794
# 9           0.001519
# 14          0.001123
# 16          0.003123

# %%
auto.query("purchased == 'Used' and vehicle_age <= 2")
# Out:
# Empty DataFrame
# Columns: [gender, type, purchased, vehicle_age, mileage, mpg, mileage_per_year, efficiency_score]
# Index: []

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gender       23 non-null     object
#  1   type         23 non-null     object
#  2   purchased    23 non-null     object
#  3   vehicle_age  23 non-null     float64
#  4   mileage      23 non-null     int64
#  5   mpg          23 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.2+ KB

# %%
len(auto)
# Out:
# 23

# %%
auto.Type = auto.Type.str.replace(" ","")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11288\4050155467.py in ?()
# ----> 1 auto.Type = auto.Type.str.replace(" ","")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Type'

# %%
auto.head()
# Out:
#    gender       type purchased  vehicle_age  mileage   mpg
# 0    Male   Mid-size      Used         15.0   127233  28.7
# 1  Female   Mid-size       New          1.0    23970  43.4
# 2    Male      Small       New          7.0    77392  24.0
# 3  Female  Large SUV      Used         14.0   185397  15.2
# 4  Female      Small       New          2.0    26001  37.0

# %%
auto.groupby(["Type"],as_index=False)[["Mileage"]].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 auto.groupby(["Type"],as_index=False)[["Mileage"]].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
auto.pivot_table(values = "Mileage", index = "Type", columns = "Purchased", aggfunc="mean")

# %%
#For each car type find the difference between maximum and minimum Vehichle Age 
a = auto.Vehicle_Age.max() - auto["Vehicle_Age"].min()

# %%
a

# %%
auto.groupby("Type")["Vehicle_Age"].agg(lambda x:x.max() - x.min()).to_frame()

# %%
#Print average mileage for each car type. Average of mileages should be grouped into columns as New and Used, as shown below 
auto.head(3)
# Out:
#    gender      type purchased  vehicle_age  mileage   mpg
# 0    Male  Mid-size      Used         15.0   127233  28.7
# 1  Female  Mid-size       New          1.0    23970  43.4
# 2    Male     Small       New          7.0    77392  24.0

# %%
auto.pivot_table(values = "Mileage", index = "Type", columns = "Purchased",aggfunc="mean")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 auto.pivot_table(values = "Mileage", index = "Type", columns = "Purchased",aggfunc="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
# ...

# %%
bread = pd.read_csv("BreadBasket_DMS.csv");bread.head()

# %%
bread.columns = bread.columns.str.lower().str.replace(" ","")

# %%
bread.item.unique()
# Out:
# array(['Bread', 'Scandinavian', 'Hot chocolate', 'Jam', 'Cookies',
#        'Muffin', 'Coffee', 'Pastry', 'Medialuna', 'Tea', 'NONE',
#        'Tartine', 'Basket', 'Mineral water', 'Farm House', 'Fudge',
#        'Juice', "Ella's Kitchen Pouches", 'Victorian Sponge', 'Frittata',
#        'Hearty & Seasonal', 'Soup', 'Pick and Mix Bowls', 'Smoothies',
#        'Cake', 'Mighty Protein', 'Chicken sand', 'Coke',
#        'My-5 Fruit Shoot', 'Focaccia', 'Sandwich', 'Alfajores', 'Eggs',
#        'Brownie', 'Dulce de Leche', 'Honey', 'The BART', 'Granola',
#        'Fairy Doors', 'Empanadas', 'Keeping It Local', 'Art Tray',
#        'Bowl Nic Pitt', 'Bread Pudding', 'Adjustment', 'Truffles',
#        'Chimichurri Oil', 'Bacon', 'Spread', 'Kids biscuit', 'Siblings',
#        'Caramel bites', 'Jammie Dodgers', 'Tiffin', 'Olum & polenta',
#        'Polenta', 'The Nomad', 'Hack the stack', 'Bakewell',
#        'Lemon and coconut', 'Toast', 'Scone', 'Crepes', 'Vegan mincepie',
# ...

# %%
bread.item.str.lower().str.replace(" ","")
# Out:
# 0               bread
# 1        scandinavian
# 2        scandinavian
# 3        hotchocolate
# 4                 jam
#              ...
# 21288          coffee
# 21289             tea
# 21290          coffee
# 21291          pastry
# 21292       smoothies
# Name: item, Length: 21293, dtype: object

# %%
bread.groupby("item")["transaction"].count().sort_values(ascending = False).head(10)
# Out:
# item
# Coffee           5471
# Bread            3325
# Tea              1435
# Cake             1025
# Pastry            856
# NONE              786
# Sandwich          771
# Medialuna         616
# Hot chocolate     590
# Cookies           540
# Name: transaction, dtype: int64

# %%
bread.item.value_counts().head
# Out:
# item
# Coffee           5471
# Bread            3325
# Tea              1435
# Cake             1025
# Pastry            856
# NONE              786
# Sandwich          771
# Medialuna         616
# Hot chocolate     590
# Cookies           540
# Name: count, dtype: int64

# %%
bread.groupby("item").size().sort_values(ascending=False).head(10)
# Out:
# item
# Coffee           5471
# Bread            3325
# Tea              1435
# Cake             1025
# Pastry            856
# NONE              786
# Sandwich          771
# Medialuna         616
# Hot chocolate     590
# Cookies           540
# dtype: int64

# %%
a = bread[bread.item == "Coffee"]["transaction"].nunique()
# Out:
# 4528

# %%
bread.groupby("item").sum().sort_values(by= "item").head(5)
# Out:
#                                                                        date  \
# item
# Adjustment                                                       2016-11-09
# Afternoon with the baker  2017-01-062017-01-072017-01-082017-01-112017-0...
# Alfajores                 2016-11-012016-11-012016-11-012016-11-012016-1...
# Argentina Night           2017-03-112017-03-232017-04-022017-04-082017-0...
# Art Tray                  2016-11-082016-11-082016-11-102016-11-102016-1...
#
#                                                                        time  \
# item
# Adjustment                                                         19:49:22
# Afternoon with the baker  14:17:5913:19:0715:28:3414:15:3714:51:5618:15:...
# Alfajores                 13:11:3413:41:5315:02:2316:07:1109:18:5310:53:...
# Argentina Night           15:38:2013:44:4913:52:5408:58:1908:59:0010:43:...
# Art Tray                  12:23:1112:33:1711:32:0716:21:0513:32:2613:01:...
#
#                           transaction
# ...
